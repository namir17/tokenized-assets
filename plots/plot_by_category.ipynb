# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Dictionary of stocks
stock_dict = {
    'SLV': 'Commodity',
    'GDX': 'Commodity',
    'GDXJ': 'Commodity',
    'GLD': 'Commodity',
    'USO': 'Commodity',
    'BITO': 'Crypto',
    'GBTC': 'Crypto',
    'BITW': 'Crypto',
    'ETHE': 'Crypto',
    'BNTX': 'Large',
    'MRNA': 'Large',
    'PFE': 'Large',
    'COIN': 'Large',
    'MSTR': 'Large',
    'AAPL': 'Large',
    'ABNB': 'Large',
    'AMD': 'Large',
    'AMZN': 'Large',
    'META': 'Large',
    'GOOGL': 'Large',
    'NFLX': 'Large',
    'NVDA': 'Large',
    'PYPL': 'Large',
    'TSLA': 'Large',
    'ZM': 'Large',
    'SQ': 'Large',
    'TWTR': 'Large',
    'UBER': 'Large',
    'BABA': 'Large',
    'BILI': 'Large',
    'NOK': 'Large',
    'TSM': 'Large',
    'HOOD': 'Meme',
    'AMC': 'Meme',
    'APE': 'Meme',
    'GME': 'Meme',
    'ARKK': 'Meme',
    'TLRY': 'other',
    'GLXY': 'other',
    'WEED': 'other',
    'CRON': 'other',
    'ACB': 'other',
    'BB': 'other',
    'WNDR': 'other',
    'BYND': 'other',
    'DKNG': 'other',
    'PENN': 'other',
    'NIO': 'other',
    'SPY': 'SP500'
}

# Load data for all stocks
for stock in stock_dict:
    filename = f"/Users/namirsacic/tokenized-assets/data_analysis/processed_data/merged_data/{stock}_merged.csv"
    if os.path.exists(filename):
        df = pd.read_csv(filename)
        plt.plot(df['day'], df['premium'], label=stock)
plt.legend()
plt.show()
